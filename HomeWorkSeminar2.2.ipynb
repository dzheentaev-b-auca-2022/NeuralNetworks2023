# %% [markdown]
# __*Attribute Information:*__
# - Alcohol
# - Malic acid
# - Ash
# - Alcalinity of ash
# - Magnesium
# - Total phenols
# - Flavanoids
# - Nonflavanoid phenols
# - Proanthocyanins
# - Color intensity
# - Hue
# - OD280/OD315 of diluted wines
# - Proline
#
# __*class:*__
# - class_0
# - class_1
# - class_2
#
# This is a copy of UCI ML Wine recognition datasets. https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same region in Italy by three different cultivators. There are thirteen different measurements taken for different constituents found in the three types of wine.
#
# __*Original Owners:*__
#
# Forina, M. et al, PARVUS - An Extendible Package for Data Exploration, Classification and Correlation. Institute of Pharmaceutical and Food Analysis and Technologies, Via Brigata Salerno, 16147 Genoa, Italy.
#
# __*Citation:*__
#
# Lichman, M. (2013). UCI Machine Learning Repository [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# __*References*__
#
# (1) S. Aeberhard, D. Coomans and O. de Vel, Comparison of Classifiers in High Dimensional Settings, Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of Mathematics and Statistics, James Cook University of North Queensland. (Also submitted to Technometrics).
#
# The data was used with many others for comparing various classifiers. The classes are separable, though only RDA has achieved 100% correct classification. (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data)) (All results using the leave-one-out technique)
#
# (2) S. Aeberhard, D. Coomans and O. de Vel, “THE CLASSIFICATION PERFORMANCE OF RDA” Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of Mathematics and Statistics, James Cook University of North Queensland. (Also submitted to Journal of Chemometrics).

# %%
import torch
import random
import numpy as np
import matplotlib.pyplot as plt

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # Step 0. Data preparation

# %%
import sklearn.datasets
wine = sklearn.datasets.load_wine()
wine.data.shape
# Out:
# (178, 13)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    wine.data,
    wine.target,
    test_size=0.35,
    shuffle=True)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %% [markdown]
# # Step 1. Preparing a neural network model

# %% [markdown]
# ## Step 1.1. Model architecture

# %%
class WineNet(torch.nn.Module):
    def __init__(self, n_hidden_neurons):
        super(WineNet, self).__init__()

        self.fc1 = torch.nn.Linear(13, n_hidden_neurons)
        self.activ1 = torch.nn.Sigmoid()
        self.fc2 = torch.nn.Linear(n_hidden_neurons, n_hidden_neurons)
        self.activ2 = torch.nn.Sigmoid()
        self.fc3 = torch.nn.Linear(n_hidden_neurons, 3)
        self.sm = torch.nn.Softmax(dim = 1)

    def forward(self, x):
        x = self.fc1(x);
        x = self.activ1(x)
        x = self.fc2(x)
        x = self.activ2(x)
        x = self.fc3(x)
        return x

    def inference(self, x):
        x = self.forward(x)
        x = self.sm(x)
        return x
wine_net = WineNet(50)

# %% [markdown]
# ## Step 1.2. Loss function

# %%
loss = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ## Step 1.3. Optimizer

# %%
optimizer = torch.optim.Adam(wine_net.parameters(), lr = 0.001)

# %% [markdown]
# # Step 2. Training loop

# %%
batch_size = 10

test_accuracy_history = []
test_loss_history = []

for epoch in range(5000):
    order = np.random.permutation(len(X_train))
    for start_index in range(0, len(X_train), batch_size):
        optimizer.zero_grad()
        batch_indexes = order[start_index: start_index + batch_size]
        x_batch = X_train[batch_indexes]
        y_batch = y_train[batch_indexes]

        pred = wine_net.forward(x_batch)
        loss_value = loss(pred, y_batch)
        loss_value.backward()
        optimizer.step()
    test_preds = wine_net.forward(X_test)
    loss_value = loss(test_preds,y_test)
    test_loss_history.append(loss_value)
    test_preds = test_preds.argmax(dim = 1)
    accuracy = (test_preds == y_test).float().mean()
    test_accuracy_history.append(accuracy)

    print(accuracy)
# Out:
# tensor(0.3968)
# tensor(0.3968)
# tensor(0.3968)
# tensor(0.3968)
# tensor(0.3968)
# tensor(0.3968)
# tensor(0.4127)
# tensor(0.6349)
# tensor(0.6667)
# tensor(0.6349)
# tensor(0.6190)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6190)
# tensor(0.6825)
# tensor(0.6190)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6825)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6825)
# tensor(0.6349)
# tensor(0.6667)
# tensor(0.6825)
# tensor(0.6667)
# tensor(0.6667)
# tensor(0.6825)
# tensor(0.6825)
# tensor(0.7143)
# tensor(0.6984)
# tensor(0.7143)
# tensor(0.7778)
# tensor(0.6984)
# tensor(0.7937)
# tensor(0.7143)
# tensor(0.7302)
# tensor(0.7302)
# tensor(0.7460)
# tensor(0.8095)
# tensor(0.7619)
# tensor(0.7302)
# tensor(0.7778)
# tensor(0.7778)
# tensor(0.7302)
# tensor(0.7937)
# tensor(0.8095)
# tensor(0.7778)
# tensor(0.8095)
# tensor(0.8095)
# tensor(0.7778)
# tensor(0.7937)
# tensor(0.8095)
# tensor(0.8413)
# tensor(0.7778)
# tensor(0.7460)
# tensor(0.8254)
# tensor(0.8095)
# tensor(0.8095)
# tensor(0.8413)
# tensor(0.7143)
# tensor(0.8254)
# tensor(0.8730)
# tensor(0.8571)
# tensor(0.8730)
# tensor(0.8413)
# tensor(0.8571)
# tensor(0.8413)
# tensor(0.8571)
# tensor(0.8254)
# tensor(0.8571)
# tensor(0.8095)
# tensor(0.8730)
# tensor(0.8254)
# tensor(0.8571)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.8730)
# tensor(0.8730)
# tensor(0.8254)
# tensor(0.8413)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.8889)
# tensor(0.8730)
# tensor(0.8889)
# tensor(0.8889)
# tensor(0.8730)
# tensor(0.8730)
# tensor(0.8730)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.8571)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8413)
# tensor(0.8254)
# tensor(0.7778)
# tensor(0.8254)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8413)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.8254)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.8413)
# tensor(0.9524)
# tensor(0.8095)
# tensor(0.9524)
# tensor(0.8413)
# tensor(0.9365)
# tensor(0.8095)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.8571)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.8095)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.8730)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.8571)
# tensor(0.8730)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8571)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.7937)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.7619)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8413)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.8730)
# tensor(0.8571)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8730)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.7937)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.8730)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8571)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.8571)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# ...
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.8889)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.8889)
# tensor(0.9048)
# tensor(0.8730)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9048)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.6349)
# tensor(0.8730)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.7937)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9048)
# tensor(0.8889)
# tensor(0.8730)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9683)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9683)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9048)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.8413)
# tensor(0.8889)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9048)
# tensor(0.9683)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9524)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9365)
# tensor(0.9365)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)
# tensor(0.9206)

# %% [markdown]
# # Step 4. Homework (60 points)

# %% [markdown]
# Let's practice with WineNet. Modify the architecture so that all 13 features are accepted as input and perform the following experiments:
#
# 1. Experiment with the number of neurons in the hidden layers. Try putting a very small number. Is there a threshold value for the number of hidden neurons at which learning becomes impossible?
#
# 2. Try passing different test_size values to the train_test_split function. At what value of test_size does the network predict worse than Base Rate*? And what is the Base Rate of the wine dataset?
#
# 3. Does the training time per epoch depend on the batch size? Explore this relationship.
#
# As a report attach code and graphs that show all the necessary dependencies.

# %%
test_accuracy_neurons = []
test_loss_neurons = []

for neurons_count in range(1, 30):
  wine_net = WineNet(neurons_count)
  optimizer = torch.optim.Adam(wine_net.parameters(), lr = 0.0015)
  batch_size = 50

  for epoch in range(5000):
      order = np.random.permutation(len(X_train))
      for start_index in range(0, len(X_train), batch_size):
          optimizer.zero_grad()
          batch_indexes = order[start_index: start_index + batch_size]
          x_batch = X_train[batch_indexes]
          y_batch = y_train[batch_indexes]

          pred = wine_net.forward(x_batch)
          loss_value = loss(pred, y_batch)
          loss_value.backward()
          optimizer.step()

  test_preds = wine_net.forward(X_test)

  test_loss = loss(test_preds,y_test)

  test_preds = test_preds.argmax(dim = 1)

  test_accuracy = (test_preds == y_test).float().mean()


  test_accuracy_neurons.append((neurons_count,test_accuracy))
  test_loss_neurons.append((neurons_count, test_loss))

plt.plot(*zip(*test_accuracy_neurons))
plt.plot(*zip(*torch.tensor(test_loss_neurons)))
# Если количество нейронов меньше 25, то предсказаения сети становятся непредсказуемыми, и нет смысле её обучать

# %%
first_class_pred = []
second_class_pred = []
third_class_pred = []
no_class_pred = []
wine_net = WineNet(65)
optimizer = torch.optim.Adam(wine_net.parameters(), lr  = 0.001)
for i in range(1,100, 10) :
  X_train, X_test, y_train, y_test = train_test_split(
    wine.data,
    wine.target,
    test_size=i/100,
    shuffle=True)

  X_train = torch.FloatTensor(X_train)
  X_test = torch.FloatTensor(X_test)
  y_train = torch.LongTensor(y_train)
  y_test = torch.LongTensor(y_test)
  batch_size = 10

  for epoch in range(2000):
      order = np.random.permutation(len(X_train))
      for start_index in range(0, len(X_train), batch_size):
          optimizer.zero_grad()
          batch_indexes = order[start_index: start_index + batch_size]
          x_batch = X_train[batch_indexes]
          y_batch = y_train[batch_indexes]

          pred = wine_net.forward(x_batch)
          loss_value = loss(pred, y_batch)
          loss_value.backward()
          optimizer.step()
  preds = wine_net.forward(X_test).argmax(dim = 1)
  first_class_pred.append((i/100, np.count_nonzero(preds == 0)))
  second_class_pred.append((i/100, np.count_nonzero(preds == 1)))
  third_class_pred.append((i/100, np.count_nonzero(preds == 2)))
  no_class_pred.append((i/100, np.count_nonzero(preds>2)))

plt.plot(*zip(*first_class_pred))
plt.plot(*zip(*second_class_pred))
plt.plot(*zip(*third_class_pred))
plt.plot(*zip(*no_class_pred))
#Base rate class_0 ~33%(59), class_1 ~40%(71), class_2 ~27%(48)

# %%
first_class = [len(wine.data)*(i/100)*0.33 for i in range(1,100,10)]
second_class = [len(wine.data)*i/100*0.4 for i in range(1,100,10)]
third_class = [len(wine.data)*i/100*0.27 for i in range(1,100,10)]
x_axis = [i/100 for i in range(1,100,10)]
fg, ax = plt.subplots()
fg, ax1 = plt.subplots()
fg, ax2 = plt.subplots()


ax.plot(x_axis,first_class, label = "first_class_base")
ax1.plot(x_axis,second_class, label = "second_class_base")
ax2.plot(x_axis,third_class, label = "third_class_base")

ax.plot(*zip(*first_class_pred), label = "first_class_train")
ax1.plot(*zip(*second_class_pred), label = "second_class_train")
ax2.plot(*zip(*third_class_pred), label = "third_class_train")
#При значении split около 0.7, предсказания начинают сильно отклонятся от base rate

# %%
wine_net = WineNet(65)
batch_size = 10

X_train, X_test, y_train, y_test = train_test_split(
    wine.data,
    wine.target,
    test_size=0.35,
    shuffle=True)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

for epoch in range(5000):
    order = np.random.permutation(len(X_train))
    for start_index in range(0, len(X_train), batch_size):
        optimizer.zero_grad()
        batch_indexes = order[start_index: start_index + batch_size]
        x_batch = X_train[batch_indexes]
        y_batch = y_train[batch_indexes]

        pred = wine_net.forward(x_batch)
        loss_value = loss(pred, y_batch)
        loss_value.backward()
        optimizer.step()
#Заняло 47 секунд

# %%
wine_net = WineNet(65)
batch_size = 50

X_train, X_test, y_train, y_test = train_test_split(
    wine.data,
    wine.target,
    test_size=0.35,
    shuffle=True)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

for epoch in range(5000):
    order = np.random.permutation(len(X_train))
    for start_index in range(0, len(X_train), batch_size):
        optimizer.zero_grad()
        batch_indexes = order[start_index: start_index + batch_size]
        x_batch = X_train[batch_indexes]
        y_batch = y_train[batch_indexes]

        pred = wine_net.forward(x_batch)
        loss_value = loss(pred, y_batch)
        loss_value.backward()
        optimizer.step()
  #Заняло 11 секунд

# %%
wine_net = WineNet(65)
batch_size = 250

X_train, X_test, y_train, y_test = train_test_split(
    wine.data,
    wine.target,
    test_size=0.35,
    shuffle=True)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

for epoch in range(5000):
    order = np.random.permutation(len(X_train))
    for start_index in range(0, len(X_train), batch_size):
        optimizer.zero_grad()
        batch_indexes = order[start_index: start_index + batch_size]
        x_batch = X_train[batch_indexes]
        y_batch = y_train[batch_indexes]

        pred = wine_net.forward(x_batch)
        loss_value = loss(pred, y_batch)
        loss_value.backward()
        optimizer.step()
  #Заняло 6 секунд
  #Вывод: Чем больше размер батча, тем быстрее обучается сеть, так как уменьшается количество операций обнуления градиента и пересчёта параметров нейросети оптимизатором

# %%
np.count_nonzero(wine.target == 0)
# Out:
# 59

# %%
np.count_nonzero(wine.target == 1)
# Out:
# 71

# %%
np.count_nonzero(wine.target == 2)
# Out:
# 48
